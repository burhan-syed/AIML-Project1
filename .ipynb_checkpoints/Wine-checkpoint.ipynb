# %%
#Project 1, Wine Regression
names: ["Burhan Syed", "Gabby Mueller"]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib as mpl
import pandas as pd
import seaborn as sns
from sklearn import (datasets, metrics,
                     model_selection as skms,
                     linear_model, neighbors, dummy)

# %%
# Read in data
wine_original_df = pd.read_csv('wine_train.csv')

display(wine_original_df.info())

features_to_analyze = ['fixed_acidity',
                      'volatile_acidity',
                      'citric_acid',
                      'residual_sugar',
                      'chlorides',
                      'free_sulfur_dioxide',
                      'total_sulfur_dioxide',
                      'density',
                      'pH', 
                      'sulphates',
                      'alcohol',
                       ]

# Separate target from features
wine_tgt = wine_original_df['quality']
wine_ftrs = wine_original_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3549 entries, 0 to 3548
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3549 non-null   int64
#  1   fixed_acidity         3549 non-null   float64
#  2   volatile_acidity      3549 non-null   float64
#  3   citric_acid           3549 non-null   float64
#  4   residual_sugar        3549 non-null   float64
#  5   chlorides             3549 non-null   float64
#  6   free_sulfur_dioxide   3549 non-null   float64
#  7   total_sulfur_dioxide  3549 non-null   float64
#  8   density               3549 non-null   float64
#  9   pH                    3549 non-null   float64
#  10  sulphates             3549 non-null   float64
#  11  alcohol               3549 non-null   float64
#  12  quality               3549 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 360.6 KB
# None

# %%
#splitting for train,validtion

def split(): 
    (wine_train_ftrs, wine_validation_ftrs,
    wine_train_tgt, wine_validation_tgt) = skms.train_test_split(wine_ftrs,
                                                                 wine_tgt,
                                                                 test_size=.25)
    
    print(f'Train: {len(wine_train_tgt)/len(wine_original_df):.2f}')
    print(f'Validation: {len(wine_validation_tgt)/len(wine_original_df):.2f}')

# %%
models = {
    'lr' : linear_model.LinearRegression()
}
for k in range(1,32,2):
    models[f'{k}-NN'] = neighbors.KNeighborsRegressor(n_neighbors=k)

# %%
def compare_models(features):
    split()
    rmses = {}
    fig,ax = plt.subplots(figsize=(6,4))
    for name, model in models.items():
        cv_scores = skms.cross_val_score(model,
                                    wine_train_ftrs[features], 
                                    wine_train_tgt,
                                     cv=5,
                                     scoring='neg_root_mean_squared_error',
                                    )
        mean = cv_scores.mean()
        rmses[name] = -mean
        my_lbl="{} ; mean score: {:.3f}".format(name,mean)
        ax.plot(cv_scores,label=my_lbl)#,marker=next(markers))
        ax.set_ylim(0.0,-1,1)
        ax.set_xlabel('Fold')
        ax.set_ylabel('Neg RMSE')
        ax.legend(loc='lower center', ncol=4);

    best_model_name = min(rmses,key=rmses.get)
    print(f'Best model: {best_model_name}; RMSE: {rmses[best_model_name]:.2f}')

# %%
compare_models(features_to_analyze)
# Out:
# Train: 0.75
# Validation: 0.25
# Best model: lr; RMSE: 0.79

# %%
#trying all unique (of atleast 2) feature combinations-this is overkill, takes a while to run
from itertools import combinations
features_combos = {}
for i in range (4,len(features_to_analyze)+1):
    j = 0
    for c in combinations(features_to_analyze,i):
        j+=1
        features_combos[f'{i}.{j}'] = list(c)

combo_rmses = {}
for id,combo in features_combos.items(): 
    cv_scores = skms.cross_val_score(models['lr'], 
                                    wine_train_ftrs[combo],
                                    wine_train_tgt,
                                    cv=5,
                                    scoring='neg_root_mean_squared_error')
    combo_rmses[id] = -cv_scores.mean()
    #print(f'{id}: {combo_rmses[id]}')

best_combo_id = min(combo_rmses, key=combo_rmses.get)
print(f'Best combo: {features_combos[best_combo_id]}, RMSE: {combo_rmses[best_combo_id]:.2f}')

best_features = features_combos[best_combo_id]
# Out:
# Best combo: ['volatile_acidity', 'citric_acid', 'residual_sugar', 'free_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol'], RMSE: 0.78

# %%
#
compare_models(best_features)
# Out:
# Train: 0.75
# Validation: 0.25
# Best model: lr; RMSE: 0.78

# %%
#validate
final_model = models[best_model_name]
fit = final_model.fit(wine_train_ftrs[best_features], wine_train_tgt)
pred = fit.predict(wine_validation_ftrs[best_features])
rmse = np.sqrt(metrics.mean_squared_error(wine_validation_tgt,pred))
print(f'{best_model_name} RMSE: {rmse:.6f}')
# Out:
# lr RMSE: 0.774846

# %%
#with test
wine_test_df=pd.read_csv("wine_test.csv")

# %%
wine_test_ftrs = wine_test_df[best_features]
pred = fit.predict(wine_test_ftrs)
display(pred)
pred_rounded = np.rint(pred)
pred_asint = pred_rounded.astype(int)
display(pred_asint)
# Out:
# array([6.11497843, 5.99728192, 5.84102021, ..., 5.40674392, 6.70601188,
#        6.39194678])
# array([6, 6, 6, ..., 5, 7, 6])

# %%
submission = pd.DataFrame({'id':wine_test_df['id'], 'Predicted':pred_asint})
display(submission.head())
# Out:
#    id  Predicted
# 0   1          6
# 1   2          6
# 2   3          6
# 3   4          6
# 4   5          6

# %%
filename = 'Wine Predictions 1.csv'
submission.to_csv(filename,index=False)
print('saved to file: ' + filename)
# Out:
# saved to file: Wine Predictions 1.csv
